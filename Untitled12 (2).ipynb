# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
data=pd.read_csv("/content/crop.csv")
print(data)
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
print(data.duplicated().sum())
# Out:
# 0

# %%
scrop = data[data['temperature'] > 35 ]['label'].unique()
print(scrop)
# Out:
# ['pigeonpeas' 'mango' 'grapes' 'papaya']

# %%
wcrop = data[data['temperature'] < 20 ]['label'].unique()
print(wcrop)
# Out:
# ['maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'lentil' 'pomegranate'
#  'grapes' 'orange']

# %%
x = data.iloc[:,:-1].values
y =data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)
y_train=le.fit_transform(y_train)
y_test=le.transform(y_test)

# %%
print(le.classes_)

# %%
x_train.shape[1]

# %%
len(le.classes_)

# %%
model = Sequential()
model.add(Dense(128,activation='relu',input_shape=(x_train.shape[1],)))
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(16,activation='relu'))
model.add(Dense(len(le.classes_),activation='softmax'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history=  model.fit(x_train,y_train,epochs=50,batch_size=16,validation_split=.2)
# Out:
# Epoch 1/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9652 - loss: 0.0911 - val_accuracy: 0.9801 - val_loss: 0.0694
# Epoch 2/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9645 - loss: 0.0897 - val_accuracy: 0.9716 - val_loss: 0.0774
# Epoch 3/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9666 - loss: 0.0818 - val_accuracy: 0.9688 - val_loss: 0.0734
# Epoch 4/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9624 - loss: 0.0892 - val_accuracy: 0.9801 - val_loss: 0.0948
# Epoch 5/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9545 - loss: 0.1289 - val_accuracy: 0.9347 - val_loss: 0.1593
# Epoch 6/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9403 - loss: 0.1795 - val_accuracy: 0.9631 - val_loss: 0.2113
# Epoch 7/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9510 - loss: 0.1174 - val_accuracy: 0.9744 - val_loss: 0.0804
# Epoch 8/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9709 - loss: 0.0763 - val_accuracy: 0.9716 - val_loss: 0.0686
# Epoch 9/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9737 - loss: 0.0720 - val_accuracy: 0.9744 - val_loss: 0.0703
# Epoch 10/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9702 - loss: 0.0720 - val_accuracy: 0.9830 - val_loss: 0.0723
# Epoch 11/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9680 - loss: 0.0850 - val_accuracy: 0.9830 - val_loss: 0.0581
# Epoch 12/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9766 - loss: 0.0571 - val_accuracy: 0.9801 - val_loss: 0.0723
# Epoch 13/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9709 - loss: 0.0702 - val_accuracy: 0.9631 - val_loss: 0.0902
# Epoch 14/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9602 - loss: 0.0857 - val_accuracy: 0.9773 - val_loss: 0.0825
# Epoch 15/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9737 - loss: 0.0633 - val_accuracy: 0.9744 - val_loss: 0.0888
# Epoch 16/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9709 - loss: 0.0756 - val_accuracy: 0.9631 - val_loss: 0.1141
# Epoch 17/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9588 - loss: 0.1026 - val_accuracy: 0.9688 - val_loss: 0.0826
# Epoch 18/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9645 - loss: 0.0955 - val_accuracy: 0.9659 - val_loss: 0.1591
# Epoch 19/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9695 - loss: 0.0882 - val_accuracy: 0.9744 - val_loss: 0.0775
# Epoch 20/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9673 - loss: 0.0723 - val_accuracy: 0.9716 - val_loss: 0.1061
# Epoch 21/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9695 - loss: 0.0843 - val_accuracy: 0.9716 - val_loss: 0.0718
# Epoch 22/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9588 - loss: 0.1040 - val_accuracy: 0.9631 - val_loss: 0.0926
# Epoch 23/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9702 - loss: 0.0856 - val_accuracy: 0.9148 - val_loss: 0.2710
# Epoch 24/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9581 - loss: 0.0918 - val_accuracy: 0.9688 - val_loss: 0.1141
# Epoch 25/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9680 - loss: 0.0688 - val_accuracy: 0.9489 - val_loss: 0.1582
# Epoch 26/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9716 - loss: 0.0701 - val_accuracy: 0.9659 - val_loss: 0.1014
# Epoch 27/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9673 - loss: 0.0809 - val_accuracy: 0.9659 - val_loss: 0.1093
# Epoch 28/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9560 - loss: 0.0984 - val_accuracy: 0.9716 - val_loss: 0.0895
# Epoch 29/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9673 - loss: 0.0815 - val_accuracy: 0.9545 - val_loss: 0.1094
# Epoch 30/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9723 - loss: 0.0688 - val_accuracy: 0.9631 - val_loss: 0.1046
# Epoch 31/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9645 - loss: 0.0748 - val_accuracy: 0.9659 - val_loss: 0.0978
# Epoch 32/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9645 - loss: 0.1296 - val_accuracy: 0.9574 - val_loss: 0.1109
# Epoch 33/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9631 - loss: 0.0845 - val_accuracy: 0.9744 - val_loss: 0.1239
# Epoch 34/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9666 - loss: 0.0770 - val_accuracy: 0.9602 - val_loss: 0.1059
# Epoch 35/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9688 - loss: 0.0777 - val_accuracy: 0.9574 - val_loss: 0.1517
# Epoch 36/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9730 - loss: 0.0724 - val_accuracy: 0.9631 - val_loss: 0.1297
# Epoch 37/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9723 - loss: 0.0717 - val_accuracy: 0.9631 - val_loss: 0.1066
# Epoch 38/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9737 - loss: 0.0662 - val_accuracy: 0.9688 - val_loss: 0.0981
# Epoch 39/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9680 - loss: 0.0711 - val_accuracy: 0.9801 - val_loss: 0.0798
# Epoch 40/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9737 - loss: 0.0617 - val_accuracy: 0.9830 - val_loss: 0.0801
# Epoch 41/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9609 - loss: 0.0933 - val_accuracy: 0.9659 - val_loss: 0.1376
# Epoch 42/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9666 - loss: 0.0877 - val_accuracy: 0.9773 - val_loss: 0.0849
# Epoch 43/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9680 - loss: 0.0798 - val_accuracy: 0.9773 - val_loss: 0.0939
# Epoch 44/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9744 - loss: 0.0638 - val_accuracy: 0.9602 - val_loss: 0.0893
# Epoch 45/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9702 - loss: 0.0641 - val_accuracy: 0.9489 - val_loss: 0.1293
# Epoch 46/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9751 - loss: 0.0596 - val_accuracy: 0.9545 - val_loss: 0.1471
# Epoch 47/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9652 - loss: 0.0891 - val_accuracy: 0.9602 - val_loss: 0.1225
# Epoch 48/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9595 - loss: 0.0979 - val_accuracy: 0.9631 - val_loss: 0.0911
# Epoch 49/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9737 - loss: 0.0599 - val_accuracy: 0.9716 - val_loss: 0.0776
# Epoch 50/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9773 - loss: 0.0587 - val_accuracy: 0.9773 - val_loss: 0.0720

# %%
loss,accurecy=model.evaluate(x_test,y_test)
print("Loss:",loss)
print("Accuracy:",accurecy)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9523 - loss: 0.1370
# Loss: 0.1370154619216919
# Accuracy: 0.9522727131843567

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'],loc='upper left')
plt.show()
